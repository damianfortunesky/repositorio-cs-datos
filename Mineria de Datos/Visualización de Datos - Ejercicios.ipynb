# %% [markdown]
# # Matplotlib - Ejercicios

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Escribir un programa que pregunte al usuario por las ventas de un rango de años y muestre por pantalla un diagrama de líneas con la evolución de las ventas.

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# Escribir una función que reciba una diccionario con las notas de las asignaturas de un curso y una cadena con el nombre de un color y devuelva un diagrama de barras de las notas en el color dado.

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# Escribir una función que reciba una serie de Pandas con las notas de los alumnos de un curso y devuelva un diagrama de cajas con las notas. El diagrama debe tener el título "Distribución de notas".

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# Escribir una función que reciba una serie de Pandas con el número de ventas de un producto durante los meses de un trimestre y un título y cree un diagrama de sectores con las ventas en formato png con el titulo dado. El diagrama debe guardarse en un fichero con formato png y el título dado.

# %% [markdown]
# ## Ejercicio 5

# %% [markdown]
# Escribir una función que reciba una serie de Pandas con el número de ventas de un producto por años y una cadena con el tipo de gráfico a generar (lineas, barras, sectores, areas) y devuelva un diagrama del tipo indicado con la evolución de las ventas por años y con el título "Evolución del número de ventas".

# %% [markdown]
# ## Ejercicio 6

# %% [markdown]
# Escribir una función que reciba un dataframe de Pandas con los ingresos y gastos de una empresa por meses y devuelva un diagrama de líneas con dos líneas, una para los ingresos y otra para los gastos. El diagrama debe tener una leyenda identificando la línea de los ingresos y la de los gastos, un título con el nombre "Evolución de ingresos y gastos" y el eje y debe empezar en 0.

# %%
# Ejercicio 1

import matplotlib.pyplot as plt

def graficar_ventas_por_años():
    ventas = {}
    print("Introduce las ventas por año (escribe '0' para terminar):")
    while True:
        try:
            anio = int(input("Ingrese el año (o '0' para finalizar): "))
            if anio == 0:
                break
            venta = float(input(f"Ingrese las ventas para el año {anio}: "))
            ventas[anio] = venta  # ventas = {YYYY: FLOAT}
        except ValueError:
            print("Entrada no válida. Por favor, ingrese un número válido.")

    años = list(ventas.keys())
    ventas_lista = list(ventas.values())
    
    plt.plot(años, ventas_lista, marker='o')
    plt.title('Evolución de las ventas')
    plt.xlabel('Año')
    plt.ylabel('Ventas')
    plt.grid(True)
    plt.show()

graficar_ventas_por_años()
# Out:
# Introduce las ventas por año (escribe '0' para terminar):

# %%
# Ejercicio 2

import matplotlib.pyplot as plt

def diagrama_barras_notas(notas, color):
    asignaturas = list(notas.keys())
    valores = list(notas.values())
    
    plt.bar(asignaturas, valores, color=color)
    plt.title('Notas por Asignatura')
    plt.xlabel('Asignaturas')
    plt.ylabel('Notas')
    plt.show()

notas = {'Matemáticas': 8, 'Física': 7, 'Química': 9, 'Historia': 6}
color = 'blue'
diagrama_barras_notas(notas, color)

# %%
# Ejercicio 3

import pandas as pd
import matplotlib.pyplot as plt

def diagrama_cajas_notas(notas_serie):
    plt.boxplot(notas_serie)
    plt.title('Distribución de notas')
    plt.ylabel('Notas')
    plt.show()

notas_serie = pd.Series([8, 7, 6, 9, 7, 8, 5, 10, 6])
diagrama_cajas_notas(notas_serie)

# %%
# Ejercicio 4

import pandas as pd
import matplotlib.pyplot as plt

def diagrama_sectores_ventas(ventas_serie, titulo):
    plt.pie(ventas_serie, labels=ventas_serie.index, autopct='%1.1f%%')
    plt.title(titulo)
    plt.savefig(f'{titulo}.png')
    plt.show()

ventas_serie = pd.Series([300, 200, 100], index=['Enero', 'Febrero', 'Marzo'])
titulo = 'Ventas Trimestrales'
diagrama_sectores_ventas(ventas_serie, titulo)

# %%
#Ejercicio 5

import pandas as pd
import matplotlib.pyplot as plt

def diagrama_ventas(ventas_serie, tipo_grafico):
    plt.title('Evolución del número de ventas')
    if tipo_grafico == 'lineas':
        plt.plot(ventas_serie.index, ventas_serie.values, marker='o')
        plt.xlabel('Años')
        plt.ylabel('Ventas')
    elif tipo_grafico == 'barras':
        plt.bar(ventas_serie.index, ventas_serie.values)
        plt.xlabel('Años')
        plt.ylabel('Ventas')
    elif tipo_grafico == 'sectores':
        plt.pie(ventas_serie.values, labels=ventas_serie.index, autopct='%1.1f%%')
    elif tipo_grafico == 'areas':
        plt.fill_between(ventas_serie.index, ventas_serie.values, color="skyblue", alpha=0.4)
        plt.xlabel('Años')
        plt.ylabel('Ventas')
    plt.show()

ventas_serie = pd.Series([250, 400, 350, 500], index=[2019, 2020, 2021, 2022])
tipo_grafico = 'lineas'
diagrama_ventas(ventas_serie, tipo_grafico)

# %%
# Ejercicio 6
import pandas as pd
import matplotlib.pyplot as plt

def diagrama_ingresos_gastos(df):
    plt.plot(df.index, df['Ingresos'], label='Ingresos', marker='o')
    plt.plot(df.index, df['Gastos'], label='Gastos', marker='o')
    plt.title('Evolución de ingresos y gastos')
    plt.xlabel('Meses')
    plt.ylabel('Cantidad')
    plt.ylim(bottom=0)
    plt.legend()
    plt.grid(True)
    plt.show()

data = {'Ingresos': [4000, 3000, 5000, 4500], 'Gastos': [2000, 2500, 3000, 3500]}
df = pd.DataFrame(data, index=['Enero', 'Febrero', 'Marzo', 'Abril'])
diagrama_ingresos_gastos(df)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=657ca745-6eb9-4c68-96b5-44f61400fd46' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
