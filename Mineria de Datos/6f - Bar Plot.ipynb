# %%
# imports y datos
import matplotlib.pyplot as plt
import numpy as np

arts = ['PANTALÓN', 'REMERA', 'BLUSA', 'CAMISA', 'POLLERA', 'ABRIGO']
stock = [1524, 2684, 800, 1756, 1008, 3521]

plt.bar(arts, stock)
plt.show()

# %%
# COLORES Y TAMAÑO
plt.bar(arts, stock, width=0.5, color=['blue', 'plum', 'teal', 'hotpink', 'aqua', 'pink'])
plt.show()

# %%
# cambiar nombre de las variables en el eje x con xticks y rotation
plt.bar(arts, stock, width=0.5, color=['blue', 'plum', 'teal', 'hotpink', 'aqua', 'pink'])
plt.xticks(np.arange(6),('Pantalón','Remera','Blusa','Camisa','Pollera','Abrigo'))
plt.show()

# %%
# barh
plt.barh(arts, stock)
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=657ca745-6eb9-4c68-96b5-44f61400fd46' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
